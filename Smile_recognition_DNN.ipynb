# %% [markdown]
# <a href="https://colab.research.google.com/github/kashifalikhan36/Machine_learning_Resources/blob/main/Smile_recognition_DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install keras

# %%
from PIL import Image
import os
import numpy as np
from keras.models import Sequential  # Corrected import
from keras.layers import Dense, Flatten
from keras.optimizers import Adam

# %%
pixel_intensities=[]
label=[]
for filename in os.listdir("./"):
  if filename[0:5]=="happy":
    label.append([1,0])
    img=Image.open(filename).convert("1")
    pixel_intensities.append(list(img.getdata()))
  elif filename[0:3]=="sad":
    label.append([0,1])
    img=Image.open(filename).convert("1")
    pixel_intensities.append(list(img.getdata()))
  else:
    pass

pixel_intensities=np.array(pixel_intensities)/255
label=np.array(label)
model=Sequential()
model.add(Dense(1024,activation="relu"))
model.add(Dense(512,activation="relu"))
model.add(Dense(128,activation="relu"))
model.add(Dense(2,activation="softmax"))

optimizer=Adam(learning_rate=0.001)
model.compile(optimizer=optimizer,loss="categorical_crossentropy",metrics=["accuracy"])

# %%
print(pixel_intensities.shape)
print(label.shape)
# Out:
# (20, 1024)
# (20, 2)

# %%
model=Sequential()
model.add(Dense(1024,activation="relu"))
model.add(Dense(512,activation="relu"))
model.add(Dense(128,activation="relu"))
model.add(Dense(2,activation="softmax"))

optimizer=Adam(learning_rate=0.001)
model.compile(optimizer=optimizer,loss="categorical_crossentropy",metrics=["accuracy"])

# %%
model.fit(pixel_intensities,label,epochs=1000,batch_size=20,verbose=2)
# Out:
# Epoch 1/1000
# 1/1 - 0s - 41ms/step - accuracy: 0.5000 - loss: 0.7409
# Epoch 2/1000
# 1/1 - 0s - 43ms/step - accuracy: 0.5000 - loss: 6.5686
# Epoch 3/1000
# 1/1 - 0s - 56ms/step - accuracy: 0.5000 - loss: 3.0448
# Epoch 4/1000
# 1/1 - 0s - 44ms/step - accuracy: 0.5000 - loss: 1.0328
# Epoch 5/1000
# 1/1 - 0s - 61ms/step - accuracy: 0.5000 - loss: 1.1269
# Epoch 6/1000
# 1/1 - 0s - 56ms/step - accuracy: 0.5000 - loss: 0.7094
# Epoch 7/1000
# 1/1 - 0s - 55ms/step - accuracy: 0.5000 - loss: 0.8252
# Epoch 8/1000
# 1/1 - 0s - 50ms/step - accuracy: 0.6500 - loss: 0.5872
# Epoch 9/1000
# 1/1 - 0s - 54ms/step - accuracy: 0.5000 - loss: 0.7499
# Epoch 10/1000
# 1/1 - 0s - 55ms/step - accuracy: 0.8500 - loss: 0.5480
# Epoch 11/1000
# 1/1 - 0s - 57ms/step - accuracy: 0.5000 - loss: 0.6641
# Epoch 12/1000
# 1/1 - 0s - 76ms/step - accuracy: 0.6000 - loss: 0.5315
# Epoch 13/1000
# 1/1 - 0s - 147ms/step - accuracy: 0.6000 - loss: 0.5484
# Epoch 14/1000
# ...

# %%
test_image1=Image.open("happy_test.png").convert("1")
test_image2=Image.open("sad_test.png").convert("1")
test_image1=list(test_image1.getdata())
test_image2=test_image2.getdata()
pixel_intensities_test=[]
pixel_intensities_test.append(test_image1)
pixel_intensities_test.append(test_image2)
pixel_intensities_test=np.array(pixel_intensities_test)/255
model.predict(pixel_intensities_test).round(k)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# array([[1., 0.],
#        [0., 1.]], dtype=float32)

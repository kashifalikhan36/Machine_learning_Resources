# %% [markdown]
# <a href="https://colab.research.google.com/github/kashifalikhan36/Machine_learning_in_1_week/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
import matplotlib.pyplot as plt

# %%
digits=load_digits()

# %%
load_digits().keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
feature=load_digits().data
target=load_digits().target

# %%
pca=PCA(n_components=10)
new_feature=pca.fit_transform(feature)

# %%
new_feature
# Out:
# array([[ -1.25946645, -21.27488348,   9.46305462, ...,  -2.55347036,
#           0.58184214,  -3.62569695],
#        [  7.9576113 ,  20.76869896,  -4.43950604, ...,   4.61593641,
#          -3.58745013,   1.07470456],
#        [  6.99192297,   9.95598641,  -2.95855808, ...,  16.41519983,
#          -0.7192329 ,  -4.25580548],
#        ...,
#        [ 10.8012837 ,   6.96025223,  -5.59955453, ...,   7.4150719 ,
#           3.96158533,  13.06509519],
#        [ -4.87210009, -12.42395362,  10.17086635, ...,   4.35789156,
#          -3.93924173,  13.14525475],
#        [ -0.34438963,  -6.36554919, -10.77370849, ...,  -0.66902071,
#           4.11316505,  12.56200443]])

# %%
colors=['black','blue','red','orange','yellow','cyan','purple','white','gray','lime']
for i in range(len(colors)):
  px = new_feature[:,0][target==i]
  py = new_feature[:,1][target==i]
  plt.scatter(px,py,c=colors[i])
  plt.legend(digits.target_names)

plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
pca.explained_variance_ratio_.sum()
# Out:
# 0.7382267688459531

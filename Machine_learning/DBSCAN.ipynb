# %% [markdown]
# <a href="https://colab.research.google.com/github/kashifalikhan36/Machine_learning_in_1_week/blob/main/DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn import datasets
import numpy as np

# %%
X, y = datasets.make_moons(n_samples=1500, noise=0.05)

# %%
x1=X[:,0]
x2=X[:,1]

# %%
plt.scatter(x1,x2,s=5)

# %%
dbscan=DBSCAN(eps=0.1)
dbscan.fit(X)
# Out:
# DBSCAN(eps=0.1)

# %%
y_pred=dbscan.labels_.astype(int)

# %%
colors=np.array(['#ff0000','#00ff00'])
plt.scatter(x1,x2,s=5,color=colors[y_pred])

# %% [markdown]
# <a href="https://colab.research.google.com/github/kashifalikhan36/Machine_learning_Resources/blob/main/Deep_Neural_network_XOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# %%
Train=np.array([[0,0],[0,1],[1,0],[1,1]],dtype=np.float32)
tar=np.array([[0],[1],[1],[0]],dtype=np.float32)

# %%
model=Sequential()
model.add(Dense(16,input_dim=2,activation='relu'))
model.add(Dense(16,input_dim=16,activation='relu'))
model.add(Dense(16,input_dim=16,activation='relu'))
model.add(Dense(16,input_dim=16,activation='relu'))
model.add(Dense(16,input_dim=16,activation='relu'))
model.add(Dense(16,input_dim=16,activation='relu'))
model.add(Dense(16,input_dim=16,activation='relu'))
model.add(Dense(16,input_dim=16,activation='relu'))
model.add(Dense(16,input_dim=16,activation='relu'))
model.add(Dense(16,input_dim=16,activation='relu'))
model.add(Dense(16,input_dim=16,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error',optimizer='adam',metrics=['binary_accuracy'])

# %%
model.fit(Train,tar,epochs=1000,verbose=2)
# Out:
# Epoch 1/1000
# 1/1 - 4s - 4s/step - binary_accuracy: 0.7500 - loss: 0.2500
# Epoch 2/1000
# 1/1 - 0s - 34ms/step - binary_accuracy: 0.5000 - loss: 0.2499
# Epoch 3/1000
# 1/1 - 0s - 30ms/step - binary_accuracy: 0.5000 - loss: 0.2499
# Epoch 4/1000
# 1/1 - 0s - 59ms/step - binary_accuracy: 0.5000 - loss: 0.2499
# Epoch 5/1000
# 1/1 - 0s - 27ms/step - binary_accuracy: 0.5000 - loss: 0.2499
# Epoch 6/1000
# 1/1 - 0s - 26ms/step - binary_accuracy: 0.5000 - loss: 0.2498
# Epoch 7/1000
# 1/1 - 0s - 27ms/step - binary_accuracy: 0.5000 - loss: 0.2497
# Epoch 8/1000
# 1/1 - 0s - 28ms/step - binary_accuracy: 0.7500 - loss: 0.2497
# Epoch 9/1000
# 1/1 - 0s - 30ms/step - binary_accuracy: 0.7500 - loss: 0.2496
# Epoch 10/1000
# 1/1 - 0s - 28ms/step - binary_accuracy: 0.7500 - loss: 0.2495
# Epoch 11/1000
# 1/1 - 0s - 29ms/step - binary_accuracy: 0.7500 - loss: 0.2494
# Epoch 12/1000
# 1/1 - 0s - 29ms/step - binary_accuracy: 0.7500 - loss: 0.2493
# Epoch 13/1000
# ...

# %%
model.predict(Train).round()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# array([[0.],
#        [1.],
#        [1.],
#        [0.]], dtype=float32)
